# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhavjalani/Hello-ML/blob/main/min_max_hello_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler

# %%
data=pd.read_csv("iris.csv")
#Importing csv as dataframe
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
print(data)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#Doing label encoding for species column
specie = data.pop('species')
print (specie)
for i in range(len(specie)):
    if specie[i]=='setosa':
        specie[i] = 0
    if specie[i]=='versicolor':
        specie[i] = 1
    if specie[i] == 'virginica':
        specie[i] = 2
print(specie)
data.insert(4,'species',specie)
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: species, Length: 150, dtype: object

# %%
#Converting to numpy array
ar=data.to_numpy()
print(ar)
print(type(ar))
# Out:
# [[5.1 3.5 1.4 0.2 0]
#  [4.9 3.0 1.4 0.2 0]
#  [4.7 3.2 1.3 0.2 0]
#  [4.6 3.1 1.5 0.2 0]
#  [5.0 3.6 1.4 0.2 0]
#  [5.4 3.9 1.7 0.4 0]
#  [4.6 3.4 1.4 0.3 0]
#  [5.0 3.4 1.5 0.2 0]
#  [4.4 2.9 1.4 0.2 0]
#  [4.9 3.1 1.5 0.1 0]
#  [5.4 3.7 1.5 0.2 0]
#  [4.8 3.4 1.6 0.2 0]
#  [4.8 3.0 1.4 0.1 0]
#  [4.3 3.0 1.1 0.1 0]
#  [5.8 4.0 1.2 0.2 0]
#  [5.7 4.4 1.5 0.4 0]
#  [5.4 3.9 1.3 0.4 0]
#  [5.1 3.5 1.4 0.3 0]
#  [5.7 3.8 1.7 0.3 0]
#  [5.1 3.8 1.5 0.3 0]
#  [5.4 3.4 1.7 0.2 0]
#  [5.1 3.7 1.5 0.4 0]
#  [4.6 3.6 1.0 0.2 0]
#  [5.1 3.3 1.7 0.5 0]
#  [4.8 3.4 1.9 0.2 0]
#  [5.0 3.0 1.6 0.2 0]
#  [5.0 3.4 1.6 0.4 0]
#  [5.2 3.5 1.5 0.2 0]
#  [5.2 3.4 1.4 0.2 0]
#  [4.7 3.2 1.6 0.2 0]
#  [4.8 3.1 1.6 0.2 0]
#  [5.4 3.4 1.5 0.4 0]
#  [5.2 4.1 1.5 0.1 0]
#  [5.5 4.2 1.4 0.2 0]
#  [4.9 3.1 1.5 0.1 0]
#  [5.0 3.2 1.2 0.2 0]
#  [5.5 3.5 1.3 0.2 0]
#  [4.9 3.1 1.5 0.1 0]
#  [4.4 3.0 1.3 0.2 0]
#  [5.1 3.4 1.5 0.2 0]
#  [5.0 3.5 1.3 0.3 0]
#  [4.5 2.3 1.3 0.3 0]
#  [4.4 3.2 1.3 0.2 0]
# ...

# %%
#Dropping species column
newar=np.delete(ar, np.s_[4], axis=1)
print(newar)
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.0 1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.0 3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.0 3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.0 1.4 0.1]
#  [4.3 3.0 1.1 0.1]
#  [5.8 4.0 1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.0 0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.0 3.0 1.6 0.2]
#  [5.0 3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.0 3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.1 1.5 0.1]
#  [4.4 3.0 1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.0 3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.0 3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.0 1.4 0.3]
#  [5.1 3.8 1.6 0.2]
# ...

# %%
#Min max scaling
min_max_scaler = preprocessing.MinMaxScaler()
ar_minmax = min_max_scaler.fit_transform(newar)
ar_minmax
# Out:
# array([[0.22222222, 0.625     , 0.06779661, 0.04166667],
#        [0.16666667, 0.41666667, 0.06779661, 0.04166667],
#        [0.11111111, 0.5       , 0.05084746, 0.04166667],
#        [0.08333333, 0.45833333, 0.08474576, 0.04166667],
#        [0.19444444, 0.66666667, 0.06779661, 0.04166667],
#        [0.30555556, 0.79166667, 0.11864407, 0.125     ],
#        [0.08333333, 0.58333333, 0.06779661, 0.08333333],
#        [0.19444444, 0.58333333, 0.08474576, 0.04166667],
#        [0.02777778, 0.375     , 0.06779661, 0.04166667],
#        [0.16666667, 0.45833333, 0.08474576, 0.        ],
#        [0.30555556, 0.70833333, 0.08474576, 0.04166667],
#        [0.13888889, 0.58333333, 0.10169492, 0.04166667],
#        [0.13888889, 0.41666667, 0.06779661, 0.        ],
#        [0.        , 0.41666667, 0.01694915, 0.        ],
#        [0.41666667, 0.83333333, 0.03389831, 0.04166667],
#        [0.38888889, 1.        , 0.08474576, 0.125     ],
# ...
